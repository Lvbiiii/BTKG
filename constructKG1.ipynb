# %%
from py2neo import Graph,Node,Relationship,NodeMatcher,RelationshipMatcher

# %%
from utils import *

# %%
import numpy as np
# from Bio import Entrez
from biotoolsJSONParser import getSimpleInfo,downloadBiotoolsJson,getMaxPage

# %%
graph=Graph("http://localhost:7474",auth=("neo4j","zzz123456"),name="neo4j")
matcher=NodeMatcher(graph)
EDAM_data=[]
header=[]
email = 'rongzhao_cn@163.com'
path='D:\\dataset\\Biotools\\'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\py2neo\client\__init__.py:806, in ConnectionPool.acquire(self, force_reset, can_overfill)
#     804 try:
#     805     # Plan A: select a free connection from the pool
# --> 806     cx = self._free_list.popleft()
#     807 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File D:\a_software\anaconda\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# ...

# %%
edamDict=loadNpy('../data/output/edamDict.npy').item()
print(len(edamDict))
